# %% [markdown]
# ## Exception
# Exception handling in Python allows us to manage errors gracefully without crashing the program. It involves using `try`, `except`, `else`, and `finally` blocks to catch and handle exceptions.
#
# ### What are exceptions?
# Exceptions are events that occur during the execution of a program that disrupt the normal flow of instructions. Common examples of exceptions include division by zero, file not found errors, and type errors.
#
# - ZeroDivisionError: Raised when a division by zero occurs.
# - FileNotFoundError: Raised when trying to open a file that does not exist.
# - TypeError: Raised when an operation is performed on an inappropriate type.
# - ValueError: Raised when a function receives an argument of the right type but inappropriate value.
# - IndexError: Raised when trying to access an index that is out of range in a list or tuple.
# - KeyError: Raised when trying to access a dictionary key that does not exist.
# - ImportError: Raised when an import statement fails to find the module definition or when a module cannot be loaded.
#
# ### How to handle exceptions?
# To handle exceptions in Python, we use the `try` and `except` blocks. The `try` block contains the code that may raise an exception, while the `except` block contains the code that will be executed if an exception occurs.
#
# ```python
# try:
#     # Code that may raise an exception
#     result = 10 / 0
# except ZeroDivisionError:
#     # Code to handle the exception
#     print("You cannot divide by zero!")
# ```
#
# we also use `else` and `finally` blocks to provide additional functionality. for example, the `else` block will execute if no exceptions are raised, and the `finally` block will execute regardless of whether an exception occurred or not.
#
# ```python
# try:
#     # Code that may raise an exception
#     result = 10 / 2
# except ZeroDivisionError:
#     # Code to handle the exception
#     print("You cannot divide by zero!")
# else:
#     # Code to execute if no exceptions were raised
#     print(f"The result is {result}")
# finally:
#     # Code that will always execute
#     print("Execution completed.")
# ```
#
# ### Raising Exceptions
# In Python, you can raise exceptions using the `raise` statement. This allows you to create custom exceptions or re-raise existing ones.
#
# ```python
# def divide(a, b):
#     if b == 0:
#         raise ValueError("The denominator cannot be zero.")
#     return a / b
# ```
#
# ### Conclusion
# Exception handling is a crucial part of writing robust Python programs. By using `try`, `except`, `else`, and `finally` blocks, you can manage errors effectively and ensure that your program continues to run smoothly even when unexpected situations arise.

# %%
## Try except block

try:
    a=b # This will raise a NameError because 'b' is not defined.
# except:
#     print("An error occurred: 'b' is not defined.")
except NameError as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: name 'b' is not defined

# %%
try:
    a = 10 / 0  # This will raise a ZeroDivisionError.
except ZeroDivisionError as e:
    print(f"An error occurred: {e}")
    print("Please keep the number greater than zero to avoid division by zero error.")
# Out:
# An error occurred: division by zero
# Please keep the number greater than zero to avoid division by zero error.

# %%
try:
    result = 10 / 1 # This will raise a ZeroDivisionError.
    a=b
except ZeroDivisionError as e:
    print(f"An error occurred: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
    print("Main exception get caught here.")
# Out:
# An error occurred: name 'b' is not defined

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ValueError as e:
    print(f"An error occurred: {e}")
    print("Please enter a valid integer.")
except ZeroDivisionError as e:
    print(f"An error occurred: {e}")
    print("Please enter a number greater than zero.")
except Exception as ex:
    print(f"An unexpected error occurred: {ex}")
# Out:
# An error occurred: invalid literal for int() with base 10: 'ww22'
# Please enter a valid integer.

# %%
## Try except else block

try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ValueError as e:
    print(f"An error occurred: {e}")
    print("Please enter a valid integer.")
except ZeroDivisionError as e:
    print(f"An error occurred: {e}")
    print("Please enter a number greater than zero.")
except Exception as ex:
    print(f"An unexpected error occurred: {ex}")    
else:
    print(f"The result is: {result}")  #If no exception occurs, this block will execute.
# Out:
# The result is: 0.9090909090909091

# %%
# Try except else finally block

try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ValueError as e:
    print(f"An error occurred: {e}")
    print("Please enter a valid integer.")
except ZeroDivisionError as e:
    print(f"An error occurred: {e}")
    print("Please enter a number greater than zero.")
except Exception as ex:
    print(f"An unexpected error occurred: {ex}")    
else:
    print(f"The result is: {result}")  #If no exception occurs, this block will execute.
finally:
    print("Execution completed.")  #This block will always execute, regardless of whether an exception occurred or not.
# Out:
# An error occurred: invalid literal for int() with base 10: 'eww'
# Please enter a valid integer.
# Execution completed.

# %%
## File handling and exception handling

try:
    with open("non_existent_file.txt", "r") as file:
        content = file.read()
except FileNotFoundError as e:
    print(f"An error occurred: {e}")
    print("The file does not exist.")
except Exception as ex:
    print(f"An unexpected error occurred: {ex}")
finally:
    if 'file' in locals() and not file.closed:
        file.close()
        print("File closed.")
# Out:
# An error occurred: [Errno 2] No such file or directory: 'non_existent_file.txt'
# The file does not exist.
